# %%
import sys
import numpy as np
import os

sys.path.append("../../")
sys.path.append(os.getcwd()) 

import openpopcon as pc

maxit = 600

# %%
# Initialise POPCON
sc1 = pc.POPCON()

sc1.machinename = 'negD_reactor'
sc1.R = 9
sc1.a = 3
sc1.Ip = 21
sc1.B0 = 5.86
sc1.kappa = 2
sc1.BetaN = 2.1
sc1.H = 1.12
sc1.fHe = 0.05
sc1.impfrac = 0.002


# Adjust input parameters
sc1.matlen = 50
sc1.imcharg = 54
sc1.timin = 2
sc1.volavgcurr = True
sc1.maxit = maxit

#sc1.fixed_quantity = "impfrac"

#sc1.fixed_quantity = "f_LH"
sc1.f_LH = 0.2

sc1.fixed_quantity = "Psol"
sc1.Psol_target = 20

sc1.plot_Psol  = not (sc1.fixed_quantity == "Psol")
sc1.plot_impf  = not (sc1.fixed_quantity == "impfrac")
sc1.plot_f_LH  = not (sc1.fixed_quantity == "f_LH")
# Out:
# ---------------------------------------------------------------
# --- Welcome to OpenPOPCON, a tokamak parameter scoping code ---
# ---------------------------------------------------------------

# %%
# Initialise POPCON
sc2 = pc.POPCON()

sc2.machinename = 'negD_reactor'
sc2.R = 7
sc2.a = 2.333
sc2.Ip = 15.4
sc2.B0 = 5.94
sc2.kappa = 2
sc2.BetaN = 2.7
sc2.H = 1.5
sc2.fHe = 0.05
sc2.impfrac = 0.0019


# Adjust input parameters
sc2.matlen = 50
sc2.imcharg = 54
sc2.timin = 2
sc2.volavgcurr = True
sc2.maxit = maxit

#sc2.fixed_quantity = "impfrac"

#sc2.fixed_quantity = "f_LH"
sc2.f_LH = 0.2

sc2.fixed_quantity = "Psol"
sc2.Psol_target = 20

sc2.plot_Psol  = not (sc2.fixed_quantity == "Psol")
sc2.plot_impf  = not (sc2.fixed_quantity == "impfrac")
sc2.plot_f_LH  = not (sc2.fixed_quantity == "f_LH")
# Out:
# ---------------------------------------------------------------
# --- Welcome to OpenPOPCON, a tokamak parameter scoping code ---
# ---------------------------------------------------------------

# %%
# Initialise POPCON
sc3 = pc.POPCON()

sc3.machinename = 'negD_reactor'
sc3.R = 7
sc3.a = 2.0
sc3.Ip = 13.2
sc3.B0 = 7.53
sc3.kappa = 1.85
sc3.BetaN = 2.5
sc3.H = 1.5
sc3.fHe = 0.05
sc3.impfrac = 0.002


# Adjust input parameters
sc3.matlen = 50
sc3.imcharg = 54
sc3.timin = 2
sc3.volavgcurr = True
sc3.maxit = maxit

#sc3.fixed_quantity = "impfrac"

#sc3.fixed_quantity = "f_LH"
sc3.f_LH = 0.2

sc3.fixed_quantity = "Psol"
sc3.Psol_target = 20

sc3.plot_Psol  = not (sc3.fixed_quantity == "Psol")
sc3.plot_impf  = not (sc3.fixed_quantity == "impfrac")
sc3.plot_f_LH  = not (sc3.fixed_quantity == "f_LH")
# Out:
# ---------------------------------------------------------------
# --- Welcome to OpenPOPCON, a tokamak parameter scoping code ---
# ---------------------------------------------------------------

# %%
# Run
sc1.make_popcons()
# Plot
sc1.plot_popcons()

# Run
sc2.make_popcons()
# Plot
sc2.plot_popcons()

# Run
sc3.make_popcons()
# Plot
sc3.plot_popcons()
# Out:
# ### POPCON parameters:
#   machinename    : negD_reactor
#   plotfilename   : OpenPOPCON_ARCH.pdf
#   datafilename   : OpenPOPCON_ARCH.p
#   R              : 9
#   a              : 3
#   kappa          : 2
#   B0             : 5.86
#   Ip             : 21
#   H              : 1.12
#   M_i            : 2.5
#   fHe            : 0.05
#   impfrac        : 0.002
#   impname        : Xenon
#   f_LH           : 0.2
#   fixed_quantity : Psol
#   constant_impurity: True
#   Psol_target    : 20
#   imcharg        : 54
#   eta_enh        : 1.0
#   fle            : 0.5
#   Fe             : 1.0
#   fnc            : 0.0
#   T_edge         : 0.1
#   Talpha1        : 2
#   Talpha2        : 1.5
#   n_frac_edge    : 0.4
#   nalpha1        : 2
#   nalpha2        : 1.5
#   jalpha1        : 2
#   jalpha2        : 2.25
#   override       : False
#   volavgcurr     : True
#   maxit          : 600
#   relax          : 0.9
#   nmin_frac      : 0.05
#   nmax_frac      : 1
#   timin          : 2
# ...

# %%
print(np.max(sc1.qpmat))
print(np.max(sc2.qpmat))
print(np.max(sc3.qpmat))
# Out:
# 11.924458052970616
# nan
# nan

# %%
# Initialise POPCON
sc4 = pc.POPCON()

sc4.machinename = 'negD_reactor'
sc4.R = 3.3
sc4.a = 1.1
sc4.Ip = 14.8
sc4.B0 = 23
sc4.kappa = 1.84
sc4.BetaN = 2.59
sc4.H = 1.5
sc4.fHe = 0.05
sc4.impfrac = 0.002


# Adjust input parameters
sc4.matlen = 50
sc4.imcharg = 54
sc4.timin = 2
sc4.volavgcurr = True
sc4.maxit = maxit

#sc4.fixed_quantity = "impfrac"

#sc4.fixed_quantity = "f_LH"
sc4.f_LH = 0.2

sc4.fixed_quantity = "Psol"
sc4.Psol_target = 20

sc4.plot_Psol  = not (sc4.fixed_quantity == "Psol")
sc4.plot_impf  = not (sc4.fixed_quantity == "impfrac")
sc4.plot_f_LH  = not (sc4.fixed_quantity == "f_LH")

# Run
sc4.make_popcons()
# Plot
sc4.plot_popcons()
# Out:
# ---------------------------------------------------------------
# --- Welcome to OpenPOPCON, a tokamak parameter scoping code ---
# ---------------------------------------------------------------
#
# ### POPCON parameters:
#   machinename    : negD_reactor
#   plotfilename   : OpenPOPCON_ARCH.pdf
#   datafilename   : OpenPOPCON_ARCH.p
#   R              : 3.3
#   a              : 1.1
#   kappa          : 1.84
#   B0             : 23
#   Ip             : 14.8
#   H              : 1.5
#   M_i            : 2.5
#   fHe            : 0.05
#   impfrac        : 0.002
#   impname        : Xenon
#   f_LH           : 0.2
#   fixed_quantity : Psol
#   constant_impurity: True
#   Psol_target    : 20
#   imcharg        : 54
#   eta_enh        : 1.0
#   fle            : 0.5
#   Fe             : 1.0
#   fnc            : 0.0
#   T_edge         : 0.1
#   Talpha1        : 2
#   Talpha2        : 1.5
#   n_frac_edge    : 0.4
#   nalpha1        : 2
#   nalpha2        : 1.5
#   jalpha1        : 2
# ...
